# %%
#if-else statement
a=7
if a%2==0:
    print("even")

else:
    print("odd")
# Out:
# odd

# %%
#if-elif-else
a=int(input("Enter a number:"))
if a<0:
    print("YOur number is negative number")

elif a>0:
    print("Your number is positive number")

else:
    print("your number is zero")
# Out:
# Enter a number: 5
# Your number is positive number

# %%
#while loop
#while loop

count=1

while  count<=6:
    print(count)
count+=1

# %%
import numpy as np
Temperature_data=np.array([
    [20,30,32,31,33],
    [21,22,23,24,25],
    [25,28,30,34,35],
    [30,32,35,37,38]
])

Avg_temperature=np.mean(Temperature_data,axis=1)
print("The average temperature of cities are:",Avg_temperature)
