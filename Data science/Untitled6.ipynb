# %%
from wordcloud import wordcloud 
import pandas as pd
df=pd.read_excel('matplotlib_practice_34889.xlsx')

# %%
from wordcloud import wordcloud
#selecting the specific director 
director_name='director A'
director_data=data
